# %% [markdown]
# # 仕様
#
# - 最初に英単語を格納するための空のリストを作成してください
# - 次に、以下のように、キーがアルファベット小文字の各文字で、値が0の辞書を作成してください：
#   - `'a':0, 'b':0, 'c':0, 'd':0, 'e':0, 'f':0, 'g':0, 'h':0, 'i':0, 'j':0, 'k':0, 'l':0, 'm':0, 'n':0, 'o':0, 'p':0, 'q':0, 'r':0, 's':0, 't':0, 'u':0, 'v':0, 'w':0, 'x':0, 'y':0, 'z':0`
# - そのあと、キーボードから英単語の入力を受けつけます：
#   - 未入力でリターン（エンター）キーを押されるまで、英単語の入力の受け付けを繰り返してください
#   - 入力された英単語を構成する文字を1文字ずつ確認して、登場した数を加算してください
#   - 入力された英単語は都度リストに格納してください
# - 最後に以下の内容を一覧表示してください：
#   - 入力された英単語のリストを一覧表示してください
#     - その際、ABC順に並べ替えてから表示するようにしてください
#   - 辞書を使って加算した値のうち、1文字以上あったすべての文字について「○が△個ありました」を表示してください

# %% [markdown]
# # ASSUMPTION
#
# 1. User only enter English lowercase letters
# 2. Any invalid input (with any non English lowercase letter) will be ignored

# %%
import string

l = []
d = dict.fromkeys(string.ascii_lowercase, 0)

while True:
    w = input("英単語を入力してください：")
    if not w:
        break
    if not w.isalpha() and w.islower():
        continue
    l.append(w)
    for ch in w:
        d[ch] += 1

l.sort()
print('入力した英単語：', l)

for ch, cnt in d.items():
    if cnt > 0:
        print(f'{ch}が{cnt}個ありました')
# Out:
# 入力した英単語： []
